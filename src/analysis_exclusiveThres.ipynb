# %% [markdown]
# # analyzing fluorescence response re sound intensity with exclusive thresholds

# %%
# create dataframe including metadata

import lib.fileIngest as fileIngest
import joblib

# dPaths = [
#     "/media/DATA/MAK/TL_B10_Mouse02/AA0001",
#     "/media/DATA/MAK/TL_B10_Mouse04/AA0001",
#     "/media/DATA/MAK/TL_B10_Mouse07/AA0001",
#     "/media/DATA/MAK/TL_B10_Mouse08/AA0001",
# ]
# df = fileIngest.qcamPath2table(dPaths)
# joblib.dump(df,'../data/cache/TLB10-2-4-7-8.joblib')
# df = joblib.load('../data/cache/TLB10-2-4-7-8.joblib')

dPaths = [r"C:\Manoj Data\TL_B10_Mouse04\AA0001"]
# df = fileIngest.qcamPath2table(dPaths)
df = fileIngest.qcamPath2table(dPaths, subfolder=True)
# joblib.dump(df,'../data/cache/TLB10_2_df_.joblib')
# df = joblib.load('../data/cache/TLB10_2_df_.joblib')
df
# Out:
#                                                   qcam  \
# 0    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 1    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 2    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 3    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 4    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# ..                                                 ...
# 134  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 135  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 136  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 137  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 138  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
#
#                                      dir  \
# 0    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 1    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 2    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 3    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 4    C:\Manoj Data\TL_B10_Mouse04\AA0001
# ..                                   ...
# ...

# %%
# show files that will be excluded
df[df['dB'].isna()]
# Out:
#                                                  qcam  \
# 0   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 1   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 2   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 3   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 4   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 5   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 68  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
#
#                                     dir  \
# 0   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 1   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 2   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 3   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 4   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 5   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 68  C:\Manoj Data\TL_B10_Mouse04\AA0001
#
#                                                   xsg  \
# 0   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 1   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# ...

# %%
# exclude unmatched stim data
df = df.dropna()
df
# Out:
#                                                   qcam  \
# 6    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 7    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 8    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 10   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 11   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# ..                                                 ...
# 134  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 135  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 136  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 137  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 138  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
#
#                                      dir  \
# 6    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 7    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 8    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 10   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 11   C:\Manoj Data\TL_B10_Mouse04\AA0001
# ..                                   ...
# ...

# %%
# label injection conditions
import lib.metadataProcess as metadataProcess

df['treatment'] = metadataProcess.getInjectionCond(df)
df

# view pre- and post-ZX1 trace numbers
# df.groupby('INJECTION')['qcam'].nunique()
# Out:
# C:\Users\SHY200\AppData\Local\Temp\ipykernel_22552\1018489442.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['treatment'] = metadataProcess.getInjectionCond(df)
#                                                   qcam  \
# 6    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 7    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 8    C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AAAA...
# 10   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 11   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# ..                                                 ...
# 134  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 135  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 136  C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# ...

# %%
# get image data
import pandas as pd

# df, qcam2img, qcam2header = fileIngest.loadQCamTable(df)
# df

# remove first few pre-exposing traces according to time gaps between adjacent trials (threshold: 30 sec)
df_drop, qcam2img, qcam2header = fileIngest.loadQCamTable(df, preExpose_excl=True, loopGap=30)
df_drop
# Out:
#                                                   qcam  \
# 0    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 1    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 2    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 3    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 4    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# ..                                                 ...
# 123  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 124  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 125  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 126  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 127  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
#
#                                      dir  \
# 0    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 1    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 2    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 3    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 4    C:\Manoj Data\TL_B10_Mouse04\AA0001
# ..                                   ...
# ...

# %%
# show wide-field image and response heatmap

# specify experiment and sound intensity
experiment = 0    # analyze the first mouse
dB = 80

# specify baseline and response time window
t_base = (2.0, 3.0)
t_resp = (3.3, 4.0)

import numpy as np
import matplotlib.pyplot as plt
import lib.imgProcess as imgProcess
from operator import itemgetter

# get data from the first mouse
expDir = df_drop['dir'].unique()[experiment]

# all sound intensities, pre-ZX1
# qcams = df_drop[(df_drop['dir']==expDir) & (df_drop['treatment']=='preZX1')]['qcam'].tolist()

# 80 dB, pre-ZX1
qcams = df_drop[(df_drop['dir']==expDir) & (df_drop['dB']==dB) & (df_drop['treatment']=='preZX1')]['qcam'].tolist()
rawF = np.array(itemgetter(*qcams)(qcam2img))

# calculate spatial dFF for response heatmap
_, _, imgs, spatialDFF = imgProcess.qcams2roiTrace(qcams, t_baseline = t_base, t_temporalAvg = t_resp)

fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].imshow(rawF.mean(axis=(0,-1)),'gray')
respHeat = ax[1].imshow(spatialDFF, cmap='jet')
ax[0].set_title("Wide-field", fontsize=14)
ax[1].set_title("Response heatmap", fontsize=14)
plt.colorbar(respHeat)
plt.tight_layout()
plt.show()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
# ...

# %%
# select ROI
# input ROI vertex coordinates to create a square mask

import lib.imgProcess as imgProcess

# set ROI coordinates
dmask = imgProcess.getSquareMask(45, 60, 30, 30, angle=90)

# show ROI against wide-field image and response heatmap
fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].imshow(rawF.mean(axis=(0,-1)),'gray')
respHeatROI = ax[1].imshow(spatialDFF, cmap='jet')
ax[0].plot(dmask['ROIcontour'][:, 0], dmask['ROIcontour'][:, 1], color='w', linewidth=2)
ax[1].plot(dmask['ROIcontour'][:, 0], dmask['ROIcontour'][:, 1], color='w', linewidth=2)
ax[0].set_title("Wide-field", fontsize=14)
ax[1].set_title("Response heatmap", fontsize=14)
plt.colorbar(respHeatROI)
plt.tight_layout()
plt.show()

# show ROI coordinates
dmask['ROIcontour']


# # save mask in the same folder as a `joblib`` file

# specify filename to be saved
# saveName = "response_mask"

# import os
# savePath = os.path.join(expDir, f"{saveName}.joblib")
# if os.path.exists(savePath):
#     raise FileExistsError(f"File '{savePath}' already exists. Choose a different filename or delete the existing file.")
# joblib.dump(dmask['mask'], savePath)
# print(f"Mask saved successfully to: {savePath}")
# Out:
# array([[45., 60.],
#        [75., 60.],
#        [75., 90.],
#        [45., 90.],
#        [45., 60.]])

# %%
# alternative method to select ROI
# draw polygon via UI

import lib.imgProcess as imgProcess

# long mouse click to start drawing polygon, single click to add vertices, long mouse lick to make last edge.
# optionally change stimlen and temporalAvgFrameSpan, or t_temporalAvg to isolate spatial response
# ROI mask is optionally saved in the same folder as a `joblib`` file

# draw ROI based on response heatmap
ui, dmask, _, _ = imgProcess.qcams2roiTrace(qcams, t_baseline = t_base, t_temporalAvg = t_resp, expDir = expDir)
ui

# draw ROI based on baseline heatmap
# ui_base, dmask, imgs, spatialDFF_base = imgProcess.qcams2roiTrace(qcams, baseline = True, t_baseAvg = t_base, expDir = expDir)
# ui_base
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='eae6c250-860b-40dd-bc8c-527aa111c095'>
#   <div id="ea472659-f4e5-4666-a3d2-c56e621a7a7d" data-root-id="eae6c250-860b-40dd-bc8c-527aa111c095" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# preview all traces at 80 dB pre-ZX1

import lib.signalProcess as signalProcess
import os

# import or use newly-generated ROI
roi_mask = dmask['mask']
# roi_mask = joblib.load(os.path.join(expDir, 'response_mask.joblib'))

t = signalProcess.getTimeVec(rawF.shape[-1])
F_linFilt, slope, intercept = signalProcess.subtractLinFit(t, rawF[:, roi_mask==1, :].mean(axis=(0,1)), t_base = t_base)

fig,ax = plt.subplots(3, 1, figsize=(15,10))

ax[0].plot(t, rawF[:, roi_mask==1, :].mean(axis=1).T)
ax[0].set_ylabel('raw F')
ax[0].set_title("raw F individual traces")

ax[1].plot(t, rawF[:, roi_mask==1, :].mean(axis=(0,1)), 'k-')
ax[1].plot(t, t*slope+intercept, 'b-', label='linear fit')
ax[1].set_title('raw F trace mean')
ax[1].set_ylabel('raw F')

ax[2].plot(t, F_linFilt, 'k-')
ax[2].set_title('raw F trace mean after linear fit subtraction')
ax[2].set_ylabel('raw F - linear fit + baseline')
ax[2].set_xlabel('time (s)')

for axn in ax:
    # set stimulus start point
    axn.axvline(x=t_base[1], color='r', linestyle=':')
    # get the y-axis limits
    ymin, ymax = axn.get_ylim()
    # show baseline and response time window
    axn.fill_betweenx((ymin, ymax), t_base[0], t_base[1], color='g', alpha=0.2, label='baseline window')
    axn.fill_betweenx((ymin, ymax), t_resp[0], t_resp[1], color='r', alpha=0.2, label='response window')

ax[1].legend()

fig.suptitle(f"{expDir}: {dB} dB pre-ZX1")
plt.show()

# %%
# add ROI mask, time vector, raw F, f0, dF, and dFF for each trace into metadata dataframe
# only consider fluorescence response within ROI
# negative outliers marked by `None` in columns `dF_ROI_linFilt_negExcl_butterFilt_peak`, and `dFF_ROI_linFilt_negExcl_butterFilt_peak`

# set time window to apply negative exclusive thresholds
# suggested overlapping with response time window
t_resp_excl=t_resp

# set cutoff frequency for low-pass filter
cutoff_freq = 2


# # add binary mask of ROI
df_drop['ROImask'] = df_drop.apply(lambda x: roi_mask, axis=1)

# # add time vector
df_drop['time'] = df_drop.apply(lambda x: t, axis=1)

# # add fluorescence trace (F) within ROI
# raw data
df_drop['F_ROI_raw'] = df_drop.apply(lambda x: qcam2img[x['qcam']][roi_mask==1, :].mean(axis=0), axis=1)
# processed data (subtracted linear fit and added low-pass filter)
df_drop['F_ROI_linFilt_butterFilt'] = df_drop['F_ROI_raw'].apply(lambda x: signalProcess.butterFilter(signalProcess.subtractLinFit(t, x, t_base=t_base)[0], cutoff_freq=cutoff_freq))

# # add baseline fluorescence (f0) within ROI
# raw data
df_drop['f0_ROI_raw'] = df_drop['F_ROI_raw'].apply(lambda x: signalProcess.getBaseResp(x, t, t_base=t_base)[0])
# processed data (subtracted linear fit and added low-pass filter)
df_drop['f0_ROI_linFilt_butterFilt'] = df_drop['F_ROI_linFilt_butterFilt'].apply(lambda x: signalProcess.getBaseResp(x, t, t_base=t_base)[0])

# # add dF response within ROI
# raw data
df_drop['dF_ROI_raw'] = df_drop.apply(lambda x: x['F_ROI_raw'] - x['f0_ROI_raw'], axis=1)
df_drop['dF_ROI_raw_peak'] = df_drop.apply(lambda x: signalProcess.pkDFFimg(qcam2img[x['qcam']], subLinFit=False, ROImask=roi_mask, butterFilt=False, dFResp=True, 
                                                                            negExcl=False, t_base=t_base, t_resp=t_resp), axis=1)
# processed data (subtracted linear fit, excluded negative traces, and added low-pass filter)
df_drop['dF_ROI_linFilt_butterFilt'] = df_drop.apply(lambda x: x['F_ROI_linFilt_butterFilt'] - x['f0_ROI_linFilt_butterFilt'], axis=1)
df_drop['dF_ROI_linFilt_butterFilt_peak'] = df_drop.apply(lambda x: signalProcess.pkDFFimg(qcam2img[x['qcam']], ROImask=roi_mask, cutoff_freq=cutoff_freq, dFResp=True, 
                                                                                           negExcl=False, t_base=t_base, t_resp=t_resp), axis=1)

# # add dFF response within ROI
# raw data
df_drop['dFF_ROI_raw'] = df_drop.apply(lambda x: x['dF_ROI_raw'] / x['f0_ROI_raw'], axis=1)
df_drop['dFF_ROI_raw_peak'] = df_drop.apply(lambda x: signalProcess.pkDFFimg(qcam2img[x['qcam']], subLinFit=False, ROImask=roi_mask, butterFilt=False, 
                                                                             negExcl=False, t_base=t_base, t_resp=t_resp), axis=1)
# processed data (subtracted linear fit, excluded negative traces, and added low-pass filter)
df_drop['dFF_ROI_linFilt_butterFilt'] = df_drop.apply(lambda x: x['dF_ROI_linFilt_butterFilt'] / x['f0_ROI_linFilt_butterFilt'], axis=1)
df_drop['dFF_ROI_linFilt_butterFilt_peak'] = df_drop.apply(lambda x: signalProcess.pkDFFimg(qcam2img[x['qcam']], ROImask=roi_mask, cutoff_freq=cutoff_freq, 
                                                                                            negExcl=False, t_base=t_base, t_resp=t_resp), axis=1)

# # whether the trace is an outlier with negative response (`False`)
# test sign of peak dFF response only, as the result is the same for peak dF response
df_drop['valid'] = df_drop.apply(lambda x: signalProcess.is_valid_resp(qcam2img[x['qcam']], ROImask=roi_mask, t_base=t_base, t_resp=t_resp, t_resp_excl=t_resp_excl), axis=1)

df_drop
# Out:
#                                                   qcam  \
# 0    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 1    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 2    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 3    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 4    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# ..                                                 ...
# 123  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 124  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 125  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 126  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 127  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
#
#                                      dir  \
# 0    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 1    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 2    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 3    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 4    C:\Manoj Data\TL_B10_Mouse04\AA0001
# ..                                   ...
# ...

# %%
# show traces that should be excluded:
df_drop[~df_drop.valid]
# Out:
#                                                   qcam  \
# 26   C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 62   C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 95   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 116  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 121  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 127  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
#
#                                      dir  \
# 26   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 62   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 95   C:\Manoj Data\TL_B10_Mouse04\AA0001
# 116  C:\Manoj Data\TL_B10_Mouse04\AA0001
# 121  C:\Manoj Data\TL_B10_Mouse04\AA0001
# 127  C:\Manoj Data\TL_B10_Mouse04\AA0001
#
#                                                    xsg  \
# 26   C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 62   C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 95   C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 116  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# ...

# %%
# exclude negative outliers
df_drop_drop = df_drop[df_drop.valid]
df_drop_drop
# Out:
#                                                   qcam  \
# 0    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 1    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 2    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 3    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# 4    C:\Manoj Data\TL_B10_Mouse04\AA0001\Control\AA...
# ..                                                 ...
# 122  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 123  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 124  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 125  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
# 126  C:\Manoj Data\TL_B10_Mouse04\AA0001\AA0001AZXA...
#
#                                      dir  \
# 0    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 1    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 2    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 3    C:\Manoj Data\TL_B10_Mouse04\AA0001
# 4    C:\Manoj Data\TL_B10_Mouse04\AA0001
# ..                                   ...
# ...

# %%
# plot averaged raw F, dF, and dFF traces within ROI 

# # recalculate averaged fluorescence response with updated dataframe where outliers are removed
# 80 dB, pre-ZX1
qcams = df_drop_drop[(df_drop_drop['dir']==expDir) & (df_drop_drop['dB']==dB) & (df_drop_drop['treatment']=='preZX1')]['qcam'].tolist()

# 80 dB, post-ZX1
# qcams = df_drop_drop[(df_drop_drop['dir']==expDir) & (df_drop_drop['dB']==dB) & (df_drop_drop['treatment']=='postZX1')]['qcam'].tolist()

# all sound intensities, pre-ZX1
# qcams = df_drop_drop[(df_drop_drop['dir']==expDir) & (df_drop_drop['treatment']=='preZX1')]['qcam'].tolist()

_, _, imgs, spatialDFF = imgProcess.qcams2roiTrace(qcams, t_baseline=t_base, t_temporalAvg=t_resp)


# plot averaged traces with error bars after linear fit subtraction and low-pass filter
roiTrace = imgProcess.mask2trace(imgs=imgs, spatialDFF=spatialDFF, **dmask, t_base=t_base, cutoff_freq=cutoff_freq)

# plot averaged raw traces without any processing
# roiTrace = imgProcess.mask2trace(imgs=imgs, spatialDFF=spatialDFF, **dmask, t_base=t_base, subLinFit=False, butterFilt=False)

# plot averaged traces without error bars after linear fit subtraction and low-pass filter
# roiTrace = imgProcess.mask2trace(imgs=imgs, spatialDFF=spatialDFF, **dmask, t_base=t_base, errBar=False, cutoff_freq=cutoff_freq)

roiTrace.shape
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4198423d-5385-4f54-9208-5de8cfde33f8'>
#   <div id="c29b042b-8494-4424-9f0d-2a11c39f8348" data-root-id="4198423d-5385-4f54-9208-5de8cfde33f8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# plot each individual and averaged traces for a certain sound intensity

# Specify treatment and sound intensity
treat_plot = 'preZX1'
dB_plot = 80

# Filter the DataFrame for the specific treatment and sound intensity
filtered_df = df_drop_drop[(df_drop_drop['dir']==expDir) & (df_drop_drop['treatment'] == treat_plot) & (df_drop_drop['dB'] == dB_plot)]

# Extract the traces
# Raw trace
individual_traces_dF = np.array(list(filtered_df['dF_ROI_raw'])).T
individual_traces_dFF = np.array(list(filtered_df['dFF_ROI_raw'])).T

# Filtered trace
# individual_traces_dF = np.array(list(filtered_df['dF_ROI_linFilt_butterFilt'])).T
# individual_traces_dFF = np.array(list(filtered_df['dFF_ROI_linFilt_butterFilt'])).T

# Compute the averaged traces
averaged_trace_dF = np.mean(individual_traces_dF, axis=1)
averaged_trace_dFF = np.mean(individual_traces_dFF, axis=1)

# Create the figure and axes
fig, ax = plt.subplots(2, 1, figsize=(10, 6))

# Plot individual traces in gray and averaged trace in red for dF
for i in range(individual_traces_dF.shape[1]):
    ax[0].plot(t, individual_traces_dF[:, i], color='gray', alpha=0.3, label='Individual Traces' if i == 0 else "")
ax[0].plot(t, averaged_trace_dF, color='red', linewidth=2, label='Averaged Trace')
ax[0].set_ylabel('dF', size=12)

# Plot individual traces in gray and averaged trace in red for dFF
for i in range(individual_traces_dFF.shape[1]):
    ax[1].plot(t, individual_traces_dFF[:, i], color='gray', alpha=0.3, label='Individual Traces' if i == 0 else "")
ax[1].plot(t, averaged_trace_dFF, color='red', linewidth=2, label='Averaged Trace')
ax[1].set_ylabel('dFF', size=12)
ax[1].set_xlabel('time (s)', size=12)

# Set stimulus start point and add legend for each subplot
for axn in ax:
    axn.axvline(x=t_base[1], color='k', linestyle='--')
    axn.legend()

# Add figure title
fig.suptitle(f"Individual and Averaged Traces: {treat_plot}, {dB} dB", size=14)

plt.tight_layout()
plt.show()

# %%
# plot each individual and averaged traces pre- and post-ZX1 for a certain sound intensity

# Specify sound intensity
dB_plot = 80

# Filter the DataFrame for pre-ZX1 and post-ZX1 conditions
preZX1_df = df_drop_drop[(df_drop_drop['dir']==expDir) & (df_drop_drop['treatment'] == 'preZX1') & (df_drop_drop['dB'] == dB_plot)]
postZX1_df = df_drop_drop[(df_drop_drop['dir']==expDir) & (df_drop_drop['treatment'] == 'postZX1') & (df_drop_drop['dB'] == dB_plot)]

# Extract the traces for pre-ZX1 and post-ZX1
# Raw trace
preZX1_traces_dF = np.array(list(preZX1_df['dF_ROI_raw'])).T
preZX1_traces_dFF = np.array(list(preZX1_df['dFF_ROI_raw'])).T
postZX1_traces_dF = np.array(list(postZX1_df['dF_ROI_raw'])).T
postZX1_traces_dFF = np.array(list(postZX1_df['dFF_ROI_raw'])).T

# Filtered trace
# preZX1_traces_dF = np.array(list(preZX1_df['dF_ROI_linFilt_butterFilt'])).T
# preZX1_traces_dFF = np.array(list(preZX1_df['dFF_ROI_linFilt_butterFilt'])).T
# postZX1_traces_dF = np.array(list(postZX1_df['dF_ROI_linFilt_butterFilt'])).T
# postZX1_traces_dFF = np.array(list(postZX1_df['dFF_ROI_linFilt_butterFilt'])).T

# Compute the averaged traces
preZX1_avg_dF = np.mean(preZX1_traces_dF, axis=1)
preZX1_avg_dFF = np.mean(preZX1_traces_dFF, axis=1)

postZX1_avg_dF = np.mean(postZX1_traces_dF, axis=1)
postZX1_avg_dFF = np.mean(postZX1_traces_dFF, axis=1)

# Create the figure and axes
fig, ax = plt.subplots(2, 1, figsize=(10, 6))

# Plot pre-ZX1 and post-ZX1 traces for dF
for i in range(preZX1_traces_dF.shape[1]):
    ax[0].plot(t, preZX1_traces_dF[:, i], color='lightcoral', alpha=0.4, label='pre-ZX1 Individual' if i == 0 else "")
for i in range(postZX1_traces_dF.shape[1]):
    ax[0].plot(t, postZX1_traces_dF[:, i], color='lightblue', alpha=0.4, label='post-ZX1 Individual' if i == 0 else "")
ax[0].plot(t, preZX1_avg_dF, color='red', linewidth=2, label='pre-ZX1 Averaged')
ax[0].plot(t, postZX1_avg_dF, color='blue', linewidth=2, label='post-ZX1 Averaged')
ax[0].set_ylabel('dF', size=12)

# Plot pre-ZX1 and post-ZX1 traces for dFF
for i in range(preZX1_traces_dFF.shape[1]):
    ax[1].plot(t, preZX1_traces_dFF[:, i], color='lightcoral', alpha=0.4, label='preZX1 Individual' if i == 0 else "")
for i in range(postZX1_traces_dFF.shape[1]):
    ax[1].plot(t, postZX1_traces_dFF[:, i], color='lightblue', alpha=0.4, label='postZX1 Individual' if i == 0 else "")
ax[1].plot(t, preZX1_avg_dFF, color='red', linewidth=2, label='pre-ZX1 Averaged')
ax[1].plot(t, postZX1_avg_dFF, color='blue', linewidth=2, label='post-ZX1 Averaged')
ax[1].set_ylabel('dFF', size=12)
ax[1].set_xlabel('time (s)', size=12)

# Set stimulus start point and add legend for each subplot
for axn in ax:
    axn.axvline(x=t_base[1], color='k', linestyle='--')
    axn.legend()

# Add figure title
fig.suptitle(f"Individual and Averaged Traces pre- and post-ZX1: {dB} dB", size=14)

plt.tight_layout()
plt.show()

# %%
# plot dFF (or dF) response traces across different sound intensties pre- or post-ZX1

import lib.plotting as plotting

# dFF response
plotting.plotDF_levelByTreatment(df_drop_drop, qcam2img, dFResp=False, sepPlot=True, roi_mask=roi_mask, t_base=t_base)

# dF response
# plotting.plotDF_levelByTreatment(df_drop_drop, qcam2img, dFResp=True, sepPlot=True, roi_mask=roi_mask, t_base=t_base)

# dFF response, show pre- and post-ZX1 traces in one plot
# plotting.plotDF_levelByTreatment(df_drop_drop, qcam2img, dFResp=False, sepPlot=False, roi_mask=roi_mask, t_base=t_base)

# %%
# plot dF and dFF response traces pre- and post-ZX1

import numpy as np
import matplotlib.pyplot as plt
import lib.signalProcess as signalProcess
import matplotlib.cm as cm

n_q = 2
colors = np.flipud(cm.coolwarm(np.linspace(0, 1, n_q)))

t = signalProcess.getTimeVec(imgs.shape[-1])
fig, ax = plt.subplots(2, 1, figsize=(10,8))

# all sound intensities
# for i,(a,b) in enumerate(df_drop_drop[df_drop_drop['dir']==expDir].groupby('treatment', sort=False)):
# 80 dB
for i,(a,b) in enumerate(df_drop_drop[(df_drop_drop['dir']==expDir) & (df_drop_drop['dB']==dB)].groupby('treatment', sort=False)):
    print(np.array(b['F_ROI_raw'].tolist()).shape)

    # raw data
    # dF = np.array(b['dF_ROI_raw'].tolist())
    # dFF = np.array(b['dFF_ROI_raw'].tolist())

    # processed data
    dF = np.array(b['dF_ROI_linFilt_butterFilt'].tolist())
    dFF = np.array(b['dFF_ROI_linFilt_butterFilt'].tolist())
    
    uDF, uDFpsem, uDFmsem = signalProcess.meanPlusMinusSem(dF)
    uDFF, uDFFpsem, uDFFmsem = signalProcess.meanPlusMinusSem(dFF)

    ax[0].set_xlabel('time (s)')
    ax[0].set_ylabel('dF')
    ax[1].set_xlabel('time (s)')
    ax[1].set_ylabel('dFF')
    ax[0].plot(t, uDF, '-', color=colors[i], label=a)
    ax[0].fill_between(t, uDFmsem, uDFpsem, alpha=0.2)
    ax[1].plot(t, uDFF, '-', color=colors[i], label=a)
    ax[1].fill_between(t, uDFFmsem, uDFFpsem, alpha=0.2)

ax[0].legend()
ax[1].legend()
# Out:
# (7, 200)
# (5, 200)

# %%
# plot peak response amplitudes across sound intensities

import plotly.express as px

# # histogram showing averaged peak dFF across intensities between pre- and post-ZX1
# fig = px.histogram(df_drop_drop[df_drop_drop['dir']==expDir], x="dB", y="dFF_ROI_linFilt_butterFilt_peak",
#                    color="treatment", barmode='group', histfunc='avg', height=400)

# # violin plot showing distribution of peak dFF across intensities between pre- and post-ZX1
# dFF response
fig = px.violin(df_drop_drop[df_drop_drop['dir']==expDir], y="dFF_ROI_linFilt_butterFilt_peak", x="dB", color="treatment", box=True, points='all')

# dF response
# fig = px.violin(df_drop_drop[df_drop_drop['dir']==expDir], y="dF_ROI_linFilt_butterFilt_peak", x="dB", color="treatment", box=True, points='all')

fig.show()

# %%
# plot barplots across sound intensities, pre- and post-ZX1, showing error bars

import seaborn as sns

# y_max = df_drop_drop[df_drop_drop['dir']==expDir]["dFF_ROI_linFilt_butterFilt_peak"].max()
# for a,b in df_drop_drop[df_drop_drop['dir']==expDir].groupby('treatment', sort=False):
#     plt.figure()
#     sns.barplot(b, x="dB", y="dFF_ROI_linFilt_butterFilt_peak")
#     plt.ylim(0, y_max)
#     plt.title(a)

# plot the two barplots side by side with same Y-axis scale
g = sns.FacetGrid(df_drop_drop[df_drop_drop['dir']==expDir], col="treatment", sharey=True, height=4)
g.map_dataframe(sns.barplot, x="dB", y="dFF_ROI_linFilt_butterFilt_peak")

# same for dF response
# g.map_dataframe(sns.barplot, x="dB", y="dF_ROI_linFilt_butterFilt_peak")
